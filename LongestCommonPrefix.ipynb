# %%
class Solution(object):
    def longestCommonPrefix(self,strs):
          """
          :type strs: List[str]
          :rtype: str
          """
      #Si la longitud es 1 los prefijos no existe 
          if len(strs) == 1 : 
              prefijosFinales = "".join(strs)
              return prefijosFinales
          else:
          #Acomodamos de menor a mayor
              prefijos = []
              palabrasMenorMayor = []
              while(len(strs) > 0):
                  max = strs[0]
                  for palabra in strs:
                
                      if len(palabra) > len(max) :
                           max = palabra
                  palabrasMenorMayor += [max]
                  if(max in strs):
                      del strs[strs.index(max)]
              #Reordnear de Menor a Mayor
              palabrasMenorMayor.reverse()    
              for i in range(0,len(palabrasMenorMayor)):#Solo funciona de menor a mayor 
                  #print("palabra = " + palabrasMenorMayor[i])
                  if palabrasMenorMayor[i] == palabrasMenorMayor[-1]: 
                      s = "soy el ultimo"
                      #print(s)
                  else:
                      for j in range(0,len(palabrasMenorMayor[i])):

                          #print(palabrasMenorMayor[i][j] + " es igual a " + palabrasMenorMayor[i + 1][j])
                          #print(palabrasMenorMayor[i][j] == palabrasMenorMayor[i + 1][j])
                          if(palabrasMenorMayor[i][j] == palabrasMenorMayor[i + 1][j]):

                              #print(palabrasMenorMayor[i][j + 1] +" es igual a "+ palabrasMenorMayor[i +1][j + 1])
                              #print(palabrasMenorMayor[i][j +1] == palabrasMenorMayor[i +1][j +1])
                              if(palabrasMenorMayor[i][j] == palabrasMenorMayor[i + 1][j]):                            
                                  prefijos += [palabrasMenorMayor[i][j]]
                              return prefijos

              prefijosUnicos = []    
              prefijosCasiFinales = ""
              # traverse for all elements
              for repetido in prefijos:
                  # check if exists in unique_list or not
                  if repetido not in prefijosUnicos:
                      prefijosUnicos.append(repetido)
              prefijosCasiFinales = "".join(prefijosUnicos)  
              #Comparamos resultado vs palabras para ver si son consecutivas los caracteres
              #si no son consecutivos sacamos ultimo elemento de resultado y guardamos 
              #print(prefijosCasiFinales +" es igual a "+ palabrasMenorMayor[0][:len(prefijosCasiFinales)])
              #print(prefijosCasiFinales == palabrasMenorMayor[0][:len(prefijosCasiFinales)])
              if(prefijosCasiFinales == palabrasMenorMayor[0][:len(prefijosCasiFinales)]):           
                test2 = prefijosCasiFinales
                elJuez = []

                for palabra in palabrasMenorMayor:    
                    elJuez += [palabra[:len(prefijosCasiFinales)] == prefijosCasiFinales]

                if False in elJuez : 
                    prefijosCasiFinales = ""

                return prefijosCasiFinales
              else:
                  prefijosFinales = []
                  for i in range(0,len(prefijosCasiFinales) - 1):
                      prefijosFinales += [prefijosCasiFinales[i]]

                  prefijosFinales = "".join(prefijosFinales)

                  if prefijosFinales[0] != prefijosFinales[0]: return prefijosCasiFinales
                    
                    
    
test = ["car","cir"]
longestCommonPrefix(test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-17f0defeb24b> in <module>
#      77
#      78 test = ["car","cir"]
# ---> 79 longestCommonPrefix(test)
#
# NameError: name 'longestCommonPrefix' is not defined

# %%
def longestCommonPrefix(strs):
      """
      :type strs: List[str]
      :rtype: str
      """
  #Si la longitud es 1 los prefijos no existe 
      if len(strs) == 1 : 
          prefijosFinales = "".join(strs)
          return prefijosFinales
      else:
      #Acomodamos de menor a mayor
          prefijos = []
          palabrasMenorMayor = []
          while(len(strs) > 0):
              max = strs[0]
              for palabra in strs:
              
                  if len(palabra) > len(max) :
                       max = palabra
              palabrasMenorMayor += [max]
              if(max in strs):
                  del strs[strs.index(max)]
          #Reordnear de Menor a Mayor
          palabrasMenorMayor.reverse()    

          for i in range(0,len(palabrasMenorMayor)):#Solo funciona de menor a mayor 
              #print("palabra = " + palabrasMenorMayor[i])
              if palabrasMenorMayor[i] == palabrasMenorMayor[-1]: 
                  s = "soy el ultimo"
                  #print(s)
              else:
                  for j in range(0,len(palabrasMenorMayor[i])):
                      
                      #print(palabrasMenorMayor[i][j] + " es igual a " + palabrasMenorMayor[i + 1][j])
                      #print(palabrasMenorMayor[i][j] == palabrasMenorMayor[i + 1][j])
                      if(palabrasMenorMayor[i][j] == palabrasMenorMayor[i + 1][j]):
                          
                          #print(palabrasMenorMayor[i][j + 1] +" es igual a "+ palabrasMenorMayor[i +1][j + 1])
                          #print(palabrasMenorMayor[i][j +1] == palabrasMenorMayor[i +1][j +1])
                          if(palabrasMenorMayor[i][j] == palabrasMenorMayor[i + 1][j]):                            
                              
                              prefijos += [palabrasMenorMayor[i][j]]
                              
                          
                          
          prefijosUnicos = []    
          prefijosCasiFinales = ""
          # traverse for all elements
          for repetido in prefijos:
              
              if repetido not in prefijosUnicos:
                  prefijosUnicos.append(repetido)
          prefijosCasiFinales = "".join(prefijosUnicos)  #cr
          
          #Comparamos resultado vs palabras para ver si son consecutivas los caracteres
          #si no son consecutivos sacamos ultimo elemento de resultado y guardamos 
          #print(prefijosCasiFinales +" es igual a "+ palabrasMenorMayor[0][:len(prefijosCasiFinales)])
          #print(prefijosCasiFinales == palabrasMenorMayor[0][:len(prefijosCasiFinales)])
          if(prefijosCasiFinales == palabrasMenorMayor[0][:len(prefijosCasiFinales)]):           
            test2 = prefijosCasiFinales
            elJuez = []
            
            
            for palabra in palabrasMenorMayor:    
                elJuez += [palabra[:len(prefijosCasiFinales)] == prefijosCasiFinales]
                
                
            if False in elJuez : 
                prefijosCasiFinales = ""
                return prefijosCasiFinales
          else:
            prefijosFinales = []
              
            for i in range(0,len(prefijosCasiFinales) - 1):
                
                prefijosFinales += [prefijosCasiFinales[i]]
                

            prefijosFinales = "".join(prefijosFinales)
            

            if prefijosFinales[0] != prefijosFinales[0]: 
                return prefijosCasiFinales
          return prefijosFinales
                    
                    
    
test = ["car","cir"]
longestCommonPrefix(test)
# Out:
# 'c'

# %%
test = ["reflower","flow","flight"]
test2 = "fl"
juez = []
for palabra in test:
    juez += [palabra[:len(test2)] == test2]
False in juez

# %%
"Encuentra la palabra mas grande"

palabras = ["hola","holo","halas"]

#TODO
# -->[X]Encuentra la palabra las larga y guardala en una variable  
# -->[ ]Compara variable letra por letra contra las demas palabras
# -->[ ]encuentra coincidencias 

max = palabras[0]

for palabra in palabras:
    if len(palabra) > len(max) :
         max = palabra

max

# %%
"Acomoda de menor a mayor"

palabras = ["uno","dos","tres"]
palabrasMenorMayor = []

while(len(palabras) > 0):
    
    max = palabras[0]

    for palabra in palabras:
        if len(palabra) > len(max) :
             max = palabra

    palabrasMenorMayor += [max]

    if(max in palabras):
        del palabras[palabras.index(max)]

#Reordnear de Menor a Mayor

palabrasMenorMayor.reverse()
palabrasMenorMayor
