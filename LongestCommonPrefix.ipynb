# %%
class Solution(object):
    def longestCommonPrefix(strs):
        """
        :type strs: List[str]
        :rtype: str
        """
    # Si la longitud es 1 los prefijos no existe
        if len(strs) == 1:
            prefijosFinales = "".join(strs)
            return prefijosFinales
        else:
            # Acomodamos de menor a mayor
            prefijos = []
            palabrasMenorMayor = []
            while(len(strs) > 0):
                max = strs[0]
                for palabra in strs:

                    if len(palabra) > len(max):
                        max = palabra
                palabrasMenorMayor += [max]
                if(max in strs):
                    del strs[strs.index(max)]
            # Reordnear de Menor a Mayor
            palabrasMenorMayor.reverse()

            # Caso donde las palabras son iguales
            juezCero = []  # Valida por False and True
            for i in range(0,len(palabrasMenorMayor)):
                juezCero += [palabrasMenorMayor[0] == palabrasMenorMayor[i]]

            if False in juezCero:
                
                s = "no hago nada"
            else:
                iguales = "".join(palabra)
                return iguales

            for i in range(0, len(palabrasMenorMayor)):  # Solo funciona de menor a mayor
                
                #print("palabra = " + palabrasMenorMayor[i])

                if palabrasMenorMayor[i] == palabrasMenorMayor[-1]:
                    s = "soy el ultimo"
                    # print(s)
                else:
                    juez=[]
                    for j in range(0, len(palabrasMenorMayor[i])):

                        #print(palabrasMenorMayor[i][j] + " es igual a " + palabrasMenorMayor[i + 1][j])
                        #print(palabrasMenorMayor[i][j] == palabrasMenorMayor[i + 1][j])
                        juez += [palabrasMenorMayor[i][j] == palabrasMenorMayor[i + 1][j]]    
                            
                        
                        
                        if(palabrasMenorMayor[i][j] == palabrasMenorMayor[i + 1][j]):

                            if(palabrasMenorMayor[i][j] == palabrasMenorMayor[i + 1][j]):

                                prefijos += [palabrasMenorMayor[i][j]]#Todas las letras iguales en las palabras
                
                

            prefijosUnicos = []
            prefijosCasiFinales = ""
            # traverse for all elements
            for repetido in prefijos:

                if repetido not in prefijosUnicos:
                    prefijosUnicos.append(repetido)
            prefijosCasiFinales = "".join(prefijosUnicos)
      
            prefijosFinales = []
            juezStr = []
            for boolean in juez:
                juezStr += [str(boolean).lower()]
            
            limitador = juezStr.index('false')
            
            for i in range(0,limitador):

                prefijosFinales += [prefijosCasiFinales[i]]
            prefijosFinales = "".join(prefijosFinales)
            return prefijosFinales

# %%
def longestCommonPrefix(strs):
       """
       :type strs: List[str]
       :rtype: str
       """
   # Si la longitud es 1 los prefijos no existe
       if len(strs) == 1:
           prefijosFinales = "".join(strs)
           return prefijosFinales
       else:
           # Acomodamos de menor a mayor
           prefijos = []
           palabrasMenorMayor = []
           while(len(strs) > 0):
               max = strs[0]
               for palabra in strs:
                   if len(palabra) > len(max):
                       max = palabra
               palabrasMenorMayor += [max]
               if(max in strs):
                   del strs[strs.index(max)]
           # Reordnear de Menor a Mayor
           palabrasMenorMayor.reverse()
           # Caso donde las palabras son iguales
           juezCero = []  # Valida por False and True
           for i in range(0,len(palabrasMenorMayor)):
               juezCero += [palabrasMenorMayor[0] == palabrasMenorMayor[i]]
           if False in juezCero:
               
               s = "no hago nada"
           else:
               iguales = "".join(palabra)
               return iguales
           for i in range(0, len(palabrasMenorMayor)):  # Solo funciona de menor a mayor
               
               #print("palabra = " + palabrasMenorMayor[i])
               if palabrasMenorMayor[i] == palabrasMenorMayor[-1]:
                   s = "soy el ultimo"
                   # print(s)
               else:
                   juez=[]
                   for j in range(0, len(palabrasMenorMayor[i])):
                       #print(palabrasMenorMayor[i][j] + " es igual a " + palabrasMenorMayor[i + 1][j])
                       #print(palabrasMenorMayor[i][j] == palabrasMenorMayor[i + 1][j])
                       juez += [palabrasMenorMayor[i][j] == palabrasMenorMayor[i + 1][j]]    
                           
                       
                       
                       if(palabrasMenorMayor[i][j] == palabrasMenorMayor[i + 1][j]):
                           if(palabrasMenorMayor[i][j] == palabrasMenorMayor[i + 1][j]):
                               prefijos += [palabrasMenorMayor[i][j]]#Todas las letras iguales en las palabras
               
               
           prefijosUnicos = []
           prefijosCasiFinales = ""
           # traverse for all elements
           for repetido in prefijos:
               if repetido not in prefijosUnicos:
                   prefijosUnicos.append(repetido)
           prefijosCasiFinales = "".join(prefijosUnicos)
     
           prefijosFinales = []
           juezStr = []
           for boolean in juez:
               juezStr += ["116" + str(boolean).lower()]
           
           limitador = juezStr.index('116false')
           
           for i in range(0,limitador):
               prefijosFinales += [prefijosCasiFinales[i]]
           prefijosFinales = "".join(prefijosFinales)
           return prefijosFinales

test = ["car","cir"]

longestCommonPrefix(test)
# Out:
# 'c'

# %%
test = ["reflower", "flow", "flight"]
test2 = "fl"
juez = []
for palabra in test:
    juez += [palabra[:len(test2)] == test2]
False in juez

# %%
"Encuentra la palabra mas grande"

palabras = ["hola", "holo", "halas"]

# TODO
# -->[X]Encuentra la palabra las larga y guardala en una variable
# -->[ ]Compara variable letra por letra contra las demas palabras
# -->[ ]encuentra coincidencias

max = palabras[0]

for palabra in palabras:
    if len(palabra) > len(max):
        max = palabra

max

# %%
"Acomoda de menor a mayor"

palabras = ["uno", "dos", "tres"]
palabrasMenorMayor = []

while(len(palabras) > 0):

    max = palabras[0]

    for palabra in palabras:
        if len(palabra) > len(max):
            max = palabra

    palabrasMenorMayor += [max]

    if(max in palabras):
        del palabras[palabras.index(max)]

# Reordnear de Menor a Mayor

palabrasMenorMayor.reverse()
palabrasMenorMayor
